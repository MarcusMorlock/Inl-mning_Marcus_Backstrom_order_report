# %%
from order_report import load_csv_to_dataframe

data = load_csv_to_dataframe("data", "orders.csv")

data
# Out:
#    order_id  order_date customer_id region product_category  quantity  \
# 0     O0001  2026-01-04        C018  South      Electronics       2.0
# 1     O0002  2026-03-17        C028  North      Electronics       1.0
# 2     O0003  2026-03-13        C013   West      Electronics       2.0
# 3     O0004  2026-01-21        C028   East      Electronics       3.0
# 4     O0005  2026-01-12        C025  North      Electronics       3.0
# ..      ...         ...         ...    ...              ...       ...
# 75    O0076  2026-03-16        C002   East      Electronics       4.0
# 76    O0077  2026-01-14        C020  North             Home       1.0
# 77    O0078  2026-01-09        C033   East           Sports       1.0
# 78    O0079  2026-02-16        C030  South            Books       4.0
# 79    O0080  2026-03-01        C028   East            Books       3.0
#
#     unit_price discount returned
# 0        799.0      0.0     true
# 1        499.0     0.05    false
# ...
