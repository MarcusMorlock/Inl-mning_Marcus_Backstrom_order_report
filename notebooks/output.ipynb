# %%
from order_report import load_csv_to_dataframe

data = load_csv_to_dataframe("../data/orders.csv")

data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from order_report import load_csv_to_dataframe
#       2
#       3 data = load_csv_to_dataframe("../data/orders.csv")
#       4
#
# ModuleNotFoundError: No module named 'order_report'
